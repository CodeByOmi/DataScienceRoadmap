# %%
import pandas as pd
df = pd.read_csv("../data/SuperStore_Sales_Dataset.csv")
df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)
df["Year"] = df["Order Date"].dt.year
df["Month"] = df["Order Date"].dt.month

# %% [markdown]
# # PART 1  DATA INSPECTING

# %%
df.shape
# Out:
# (5901, 23)

# %%
df.columns
# Out:
# Index(['Row ID+O6G3A1:R6', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Profit', 'Returns', 'Payment Mode', 'ind1',
#        'ind2'],
#       dtype='str')

# %%
df.head()
df.tail(2)
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name   Segment        Country  \
# 5899  Standard Class    PO-18865  Patrick O'Donnell  Consumer  United States
# 5900  Standard Class    JM-15580      Jill Matthias  Consumer  United States
#
#                City  ...         Category Sub-Category  \
# 5899  New York City  ...  Office Supplies      Binders
# 5900       Loveland  ...  Office Supplies    Fasteners
#
#                               Product Name     Sales Quantity   Profit  \
# 5899  Wilson Jones Legal Size Ring Binders   462.776        3  19.7910
# 5900                   Bagged Rubber Bands  2975.510        3  -0.6048
#
#       Returns  Payment Mode  ind1  ind2
# 5899      NaN           COD   NaN   NaN
# 5900      NaN           COD   NaN   NaN
#
# [2 rows x 23 columns]

# %%
df.dtypes
# Out:
# Row ID+O6G3A1:R6      int64
# Order ID                str
# Order Date              str
# Ship Date               str
# Ship Mode               str
# Customer ID             str
# Customer Name           str
# Segment                 str
# Country                 str
# City                    str
# State                   str
# Region                  str
# Product ID              str
# Category                str
# Sub-Category            str
# Product Name            str
# Sales               float64
# Quantity              int64
# Profit              float64
# Returns             float64
# Payment Mode            str
# ind1                float64
# ind2                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   str
#  2   Order Date        5901 non-null   str
#  3   Ship Date         5901 non-null   str
#  4   Ship Mode         5901 non-null   str
#  5   Customer ID       5901 non-null   str
#  6   Customer Name     5901 non-null   str
#  7   Segment           5901 non-null   str
#  8   Country           5901 non-null   str
#  9   City              5901 non-null   str
#  10  State             5901 non-null   str
#  11  Region            5901 non-null   str
#  12  Product ID        5901 non-null   str
#  13  Category          5901 non-null   str
#  14  Sub-Category      5901 non-null   str
#  15  Product Name      5901 non-null   str
#  16  Sales             5901 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Row ID+O6G3A1:R6        Sales     Quantity       Profit  Returns  ind1  \
# count       5901.000000  5901.000000  5901.000000  5901.000000    287.0   0.0
# mean        5022.422471   265.345589     3.781901    29.700408      1.0   NaN
# std         2877.977184   474.260645     2.212917   259.589138      0.0   NaN
# min            1.000000     0.836000     1.000000 -6599.978000      1.0   NaN
# 25%         2486.000000    71.976000     2.000000     1.795500      1.0   NaN
# 50%         5091.000000   128.648000     3.000000     8.502500      1.0   NaN
# 75%         7456.000000   265.170000     5.000000    28.615000      1.0   NaN
# max         9994.000000  9099.930000    14.000000  8399.976000      1.0   NaN
#
#        ind2
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
df.isnull().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Category"].unique()
# Out:
# <StringArray>
# ['Furniture', 'Technology', 'Office Supplies']
# Length: 3, dtype: str

# %%
df["Region"].unique()
# Out:
# <StringArray>
# ['East', 'West', 'Central', 'South']
# Length: 4, dtype: str

# %%
df.nunique()
# Out:
# Row ID+O6G3A1:R6    5900
# Order ID            3003
# Order Date           643
# Ship Date            690
# Ship Mode              4
# Customer ID          773
# Customer Name        773
# Segment                3
# Country                1
# City                 452
# State                 49
# Region                 4
# Product ID          1755
# Category               3
# Sub-Category          17
# Product Name        1742
# Sales               5109
# Quantity              14
# Profit              4739
# Returns                1
# Payment Mode           3
# ind1                   0
# ind2                   0
# dtype: int64

# %% [markdown]
# # PART 2 DATA CLEANING

# %%
df.isna().sum()
# Out:
# Row ID+O6G3A1:R6       0
# Order ID               0
# Order Date             0
# Ship Date              0
# Ship Mode              0
# Customer ID            0
# Customer Name          0
# Segment                0
# Country                0
# City                   0
# State                  0
# Region                 0
# Product ID             0
# Category               0
# Sub-Category           0
# Product Name           0
# Sales                  0
# Quantity               0
# Profit                 0
# Returns             5614
# Payment Mode           0
# ind1                5901
# ind2                5901
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Row ID+O6G3A1:R6      int64
# Order ID                str
# Order Date              str
# Ship Date               str
# Ship Mode               str
# Customer ID             str
# Customer Name           str
# Segment                 str
# Country                 str
# City                    str
# State                   str
# Region                  str
# Product ID              str
# Category                str
# Sub-Category            str
# Product Name            str
# Sales               float64
# Quantity              int64
# Profit              float64
# Returns             float64
# Payment Mode            str
# ind1                float64
# ind2                float64
# dtype: object

# %%
df[["Order Date", "Ship Date"]].head()
# Out:
#    Order Date   Ship Date
# 0  01-01-2019  07-01-2019
# 1  02-01-2019  07-01-2019
# 2  02-01-2019  07-01-2019
# 3  03-01-2019  05-01-2019
# 4  03-01-2019  08-01-2019

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], dayfirst=True)
df["Ship Date"] = pd.to_datetime(df["Ship Date"], dayfirst=True)

# %%
df[["Order Date", "Ship Date"]].dtypes
# Out:
# Order Date    datetime64[us]
# Ship Date     datetime64[us]
# dtype: object

# %%
df["Sales"].describe()
# Out:
# count    5901.000000
# mean      265.345589
# std       474.260645
# min         0.836000
# 25%        71.976000
# 50%       128.648000
# 75%       265.170000
# max      9099.930000
# Name: Sales, dtype: float64

# %%
df["Quantity"].describe()
# Out:
# count    5901.000000
# mean        3.781901
# std         2.212917
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        14.000000
# Name: Quantity, dtype: float64

# %%
df["Profit"].describe()
# Out:
# count    5901.000000
# mean       29.700408
# std       259.589138
# min     -6599.978000
# 25%         1.795500
# 50%         8.502500
# 75%        28.615000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
df[df["Profit"] < 0].shape[0]
# Out:
# 1098

# %%
df[df["Quantity"] <= 0].shape[0]
# Out:
# 0

# %% [markdown]
# # part 3 feature creation

# %%
df["Year"] = df["Order Date"].dt.year

# %%
df[["Order Date", "Year"]].head()
# Out:
#   Order Date  Year
# 0 2019-01-01  2019
# 1 2019-01-02  2019
# 2 2019-01-02  2019
# 3 2019-01-03  2019
# 4 2019-01-03  2019

# %%
df["Month"] = df["Order Date"].dt.month

# %%
df[["Order Date", "Month"]].head()
# Out:
#   Order Date  Month
# 0 2019-01-01      1
# 1 2019-01-02      1
# 2 2019-01-02      1
# 3 2019-01-03      1
# 4 2019-01-03      1

# %%
df[["Sales", "Quantity"]].head(10)
# Out:
#       Sales  Quantity
# 0    73.940         1
# 1   173.940         3
# 2   231.980         2
# 3   114.460         2
# 4    30.080         2
# 5   165.600         3
# 6   180.960         5
# 7  1592.850         7
# 8    11.880         2
# 9   959.968         4

# %%
df["Month_Name"] = df["Order Date"].dt.month_name()

# %%
df[["Order Date", "Month", "Month_Name"]].head()
# Out:
#   Order Date  Month Month_Name
# 0 2019-01-01      1    January
# 1 2019-01-02      1    January
# 2 2019-01-02      1    January
# 3 2019-01-03      1    January
# 4 2019-01-03      1    January

# %% [markdown]
# # PART 4 BUSINESS ANALYSIS

# %%
df["Sales"].sum()
# Out:
# np.float64(1565804.3232)

# %%
df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False)
# Out:
# Product Name
# 3D Systems Cube Printer, 2nd Generation, Magenta               14334.890
# Canon imageCLASS 2200 Advanced Copier                          14076.824
# Hewlett Packard LaserJet 3310 Copier                           13837.732
# GBC DocuBind TL300 Electric Binding System                     12890.258
# GBC DocuBind P400 Electric Binding System                      12577.108
#                                                                  ...
# Wilson Jones Custom Binder Spines & Labels                         4.896
# While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle        4.730
# Eldon 100 Class Desk Accessories                                   4.044
# Newell 32                                                          2.880
# Avery 479                                                          2.610
# Name: Sales, Length: 1742, dtype: float64

# %%
df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
# Out:
# Category
# Office Supplies    643707.6870
# Technology         470587.9910
# Furniture          451508.6452
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
# Out:
# Region
# West       522441.0520
# East       450234.6660
# Central    341007.5242
# South      252121.0810
# Name: Sales, dtype: float64

# %%
df.groupby("Category")["Profit"].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         90458.2486
# Office Supplies    74797.2461
# Furniture          10006.6112
# Name: Profit, dtype: float64

# %%
df.groupby("Customer Name")["Sales"].sum().sort_values(ascending=False).head(5)
# Out:
# Customer Name
# Caroline Jumper    11596.974
# Karen Ferguson     10941.274
# Seth Vernon        10751.148
# Helen Wasserman    10074.934
# Edward Hooks        9542.988
# Name: Sales, dtype: float64

# %%
df["Customer Name"].nunique()
# Out:
# 773

# %%
df["Sales"].mean()
# Out:
# np.float64(265.3455894255211)

# %%
df["Quantity"].sum()
# Out:
# np.int64(22317)

# %%
df["Profit"].sum()
# Out:
# np.float64(175262.1059)

# %%
df["Year"] = df["Order Date"].dt.year

df.groupby("Year")["Sales"].sum()
# Out:
# Year
# 2019    5.646795e+05
# 2020    1.001125e+06
# Name: Sales, dtype: float64

# %%
df["Month"] = df["Order Date"].dt.month
df.groupby("Month")["Sales"].sum().sort_index()
# Out:
# Month
# 1      73379.8050
# 2      72046.9484
# 3     115945.2278
# 4      89557.5751
# 5     117737.8382
# 6     109587.2597
# 7      99339.3790
# 8     108454.2623
# 9     193213.6769
# 10    131584.6682
# 11    210372.7908
# 12    244584.8918
# Name: Sales, dtype: float64

# %%
df.groupby("Month")["Sales"].sum().idxmax()
# Out:
# np.int32(12)

# %%
df.groupby("Month")["Sales"].sum().max()
# Out:
# np.float64(244584.8918)

# %%
df.groupby("Category")[["Sales", "Profit"]].sum().sort_values("Sales", ascending=False)
# Out:
#                        Sales      Profit
# Category
# Office Supplies  643707.6870  74797.2461
# Technology       470587.9910  90458.2486
# Furniture        451508.6452  10006.6112

# %% [markdown]
# office supplies has highest sales
#
# tecnology has highest profits

# %%
df[df["Profit"] < 0].groupby("Product Name")["Profit"].sum().sort_values().head(10)
# Out:
# Product Name
# Cubify CubeX 3D Printer Double Head Print                                     -6599.9780
# Cubify CubeX 3D Printer Triple Head Print                                     -3839.9904
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind   -3431.6730
# Lexmark MX611dhe Monochrome Laser Printer                                     -3399.9800
# GBC DocuBind P400 Electric Binding System                                     -3157.4968
# GBC Ibimaster 500 Manual ProClick Binding System                              -3120.0180
# Ibico EPK-21 Electric Binding System                                          -2929.4845
# Bush Advantage Collection Racetrack Conference Table                          -2019.2396
# GBC DocuBind TL300 Electric Binding System                                    -1650.4616
# Martin Yale Chadless Opener Electric Letter Opener                            -1349.1522
# Name: Profit, dtype: float64

# %%
df.groupby("Region")[["Sales", "Profit"]].sum().sort_values("Profit", ascending=False)
# Out:
#                Sales      Profit
# Region
# West     522441.0520  67859.9582
# East     450234.6660  53400.4243
# Central  341007.5242  27450.0071
# South    252121.0810  26551.7163

# %%
category_summary = df.groupby("Category")[["Sales", "Profit"]].sum()
category_summary["Profit_Margin_%"] = (category_summary["Profit"] / category_summary["Sales"] * 100)
category_summary.sort_values("Profit_Margin_%", ascending=False)
# Out:
#                        Sales      Profit  Profit_Margin_%
# Category
# Technology       470587.9910  90458.2486        19.222388
# Office Supplies  643707.6870  74797.2461        11.619753
# Furniture        451508.6452  10006.6112         2.216261

# %%
subcategory_summary = df.groupby("Sub-Category")[["Sales", "Profit"]].sum()
subcategory_summary.sort_values("Sales", ascending=False)
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        196563.5460  22308.9179
# Chairs        181945.9980  13406.7032
# Binders       174978.3900  17885.3759
# Storage       150341.3180  13607.0875
# Accessories   122301.0860  25336.6455
# Tables        119293.7430 -11091.6365
# Paper          99453.6120  21112.3779
# Furnishings    92691.2180   8034.4328
# Machines       91987.5610     38.1024
# Appliances     80305.2470  13166.6098
# Copiers        59735.7980  42774.5828
# Bookcases      57577.6862   -342.8883
# Art            50762.9760   3635.9257
# Supplies       36720.9860  -1654.2767
# Labels         19397.4560   2937.2212
# Envelopes      16542.4640   3508.5073
# Fasteners      15205.2380    598.4175

# %%
category_sales = df.groupby("Category")["Sales"].sum()
import matplotlib.pyplot as plt

category_sales.plot(kind="bar")

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)
plt.show()

# %%
yearly_sales = df.groupby("Year")["Sales"].sum()

yearly_sales.plot(kind="line", marker="o")

plt.title("Sales Trend by Year")
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.xticks(yearly_sales.index)
plt.show()

# %%
df.groupby("Year")["Month"].nunique()
# Out:
# Year
# 2019    12
# 2020    12
# Name: Month, dtype: int64

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()
monthly_sales.plot(kind="line",marker="o",figsize=(10, 5))

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.xticks(range(1, 13))
plt.grid(True)
plt.show()

# %%
subcategory_profit = (df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False))

subcategory_profit
# Out:
# Sub-Category
# Copiers        42774.5828
# Accessories    25336.6455
# Phones         22308.9179
# Paper          21112.3779
# Binders        17885.3759
# Storage        13607.0875
# Chairs         13406.7032
# Appliances     13166.6098
# Furnishings     8034.4328
# Art             3635.9257
# Envelopes       3508.5073
# Labels          2937.2212
# Fasteners        598.4175
# Machines          38.1024
# Bookcases       -342.8883
# Supplies       -1654.2767
# Tables        -11091.6365
# Name: Profit, dtype: float64

# %%
subcategory_profit.tail(5)
# Out:
# Sub-Category
# Fasteners      598.4175
# Machines        38.1024
# Bookcases     -342.8883
# Supplies     -1654.2767
# Tables      -11091.6365
# Name: Profit, dtype: float64

# %%
subcategory_summary = df.groupby("Sub-Category")[["Sales", "Profit"]].sum()

subcategory_summary.sort_values("Sales", ascending=False)
# Out:
#                     Sales      Profit
# Sub-Category
# Phones        196563.5460  22308.9179
# Chairs        181945.9980  13406.7032
# Binders       174978.3900  17885.3759
# Storage       150341.3180  13607.0875
# Accessories   122301.0860  25336.6455
# Tables        119293.7430 -11091.6365
# Paper          99453.6120  21112.3779
# Furnishings    92691.2180   8034.4328
# Machines       91987.5610     38.1024
# Appliances     80305.2470  13166.6098
# Copiers        59735.7980  42774.5828
# Bookcases      57577.6862   -342.8883
# Art            50762.9760   3635.9257
# Supplies       36720.9860  -1654.2767
# Labels         19397.4560   2937.2212
# Envelopes      16542.4640   3508.5073
# Fasteners      15205.2380    598.4175

# %%
loss_transactions = df[df["Profit"] < 0]

print("Number of loss-making transactions:", len(loss_transactions))
print("Total loss:", loss_transactions["Profit"].sum())
print("Average loss per loss-making transaction:", loss_transactions["Profit"].mean())
# Out:
# Number of loss-making transactions: 1098
# Total loss: -91709.7279
# Average loss per loss-making transaction: -83.52434234972678
